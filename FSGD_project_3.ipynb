# %% [markdown]
# # A Fast Parallel Stochastic Gradient Method for Matrix Factorization in Shared Memory Systems

# %% [markdown]
# Matrix factorization is known to be an effective method for recommender systems that are given only the ratings from users to items. Currently, stochastic gradient (SG) method is one of the most popular algorithms for matrix factorization. However, as a sequential approach, SG is difficult to be parallelized for handling web-scale problems. In this paper, we develop a fast parallel SG method, FPSG, for shared memory systems. By dramatically reducing the cache-miss rate and carefully addressing the load balance of threads, FPSG is more efficient than state-of-the-art parallel algorithms for matrix factorization.

# %%
import numpy as np
from scipy import sparse
import matplotlib.pyplot as plt
import time
import os
from tqdm import tqdm
from multiprocessing import Process, Queue, Pool, Array
from ctypes import c_double
from functools import partial
import multiprocessing
from multiprocessing import log_to_stderr, get_logger
import logging
from concurrent.futures import ThreadPoolExecutor
import itertools as itls
import random
from functools import reduce

# %% [markdown]
# #### Data input

# %%
path = os.getcwd().replace('projet', 'data/')
r = np.genfromtxt(path + 'ratings.dat', delimiter="::", dtype=None)

# Matrice r
row = np.array([y[0] for y in r[::, :1]])
col = np.array([y[0] for y in r[::, 1:2]])
values = np.array([y[0] for y in r[::, 2:3]])
M = sparse.coo_matrix((values, (row, col)))
Mc = M.tocsr()

# Jeu de données réduit
x = 100000
y = 100000
A = Mc[:x, :y]
id_x = A.nonzero()[0]
id_y = A.nonzero()[1]
nb_ratings = len(A.data)

# %%
print(A)
# Out:
#   (1, 1)	5
#   (1, 48)	5
#   (1, 150)	5
#   (1, 260)	4
#   (1, 527)	5
#   (1, 531)	4
#   (1, 588)	4
#   (1, 594)	4
#   (1, 595)	5
#   (1, 608)	4
#   (1, 661)	3
#   (1, 720)	3
#   (1, 745)	3
#   (1, 783)	4
#   (1, 914)	3
#   (1, 919)	4
#   (1, 938)	4
#   (1, 1022)	5
#   (1, 1028)	5
#   (1, 1029)	5
#   (1, 1035)	5
#   (1, 1097)	4
#   (1, 1193)	5
#   (1, 1197)	3
#   (1, 1207)	4
#   :	:
#   (6040, 3334)	5
#   (6040, 3342)	3
#   (6040, 3359)	4
#   (6040, 3361)	2
#   (6040, 3362)	4
#   (6040, 3388)	1
#   (6040, 3418)	3
#   (6040, 3421)	3
#   (6040, 3422)	3
#   (6040, 3424)	2
#   (6040, 3449)	3
#   (6040, 3471)	4
#   (6040, 3504)	4
#   (6040, 3505)	4
#   (6040, 3521)	5
#   (6040, 3524)	1
#   (6040, 3543)	4
#   (6040, 3547)	4
#   (6040, 3552)	2
#   (6040, 3671)	4
#   (6040, 3683)	4
#   (6040, 3703)	4
#   (6040, 3735)	4
#   (6040, 3751)	4
#   (6040, 3819)	5

# %% [markdown]
# #### Fonction RMSE

# %%
latent_dim = 20
p = np.random.rand(latent_dim, A.shape[0])/10
q = np.random.rand(latent_dim, A.shape[1])/10
r_hat = np.dot(np.transpose(p), q)

# %%
def RMSE(A, r_hat, id_x, id_y, nb_ratings):
    rmse = 0
    for i, j in zip(id_x, id_y):
        rmse += (A[i, j] - r_hat[i, j])**2
    return np.sqrt(rmse/nb_ratings)

# %%
start = time.time()
rmse = RMSE(A, r_hat, id_x, id_y, nb_ratings)
print('Executed in:', time.time()-start)
# Out:
# Executed in: 36.63531994819641

# %%
def map_func(i, j):
    return (A[i, j] - r_hat[i, j])**2

def reduce_func(a,b):
    return a+b

def RMSE_map(A, r_hat, id_x, id_y, nb_ratings):
    p = multiprocessing.Pool(processes=4)
    return np.sqrt(reduce(reduce_func, p.starmap(map_func, zip(id_x, id_y)))/nb_ratings)

# %%
start = time.time()
rmse_map = RMSE_map(A, r_hat, id_x, id_y, nb_ratings)
print('Executed in:', time.time()-start)
# Out:
# Executed in: 12.40776777267456

# %%
print('Exact?', rmse_map-rmse)
# Out:
# Exact? 0.0

# %% [markdown]
# #### Input data - display management

# %%
print_iter = 1
time_break = 900.

# %% [markdown]
# #### Input data - Parameters initialisation

# %%
# Input definition
latent_dim = 20
learning_rate = 0.01
l_p = 0.05
l_q = 0.05
stop_cond = 0.1
nb_process = 10

rmse = 6

# %% [markdown]
# ## I - Reference algorithm - Sequential method

# %% [markdown]
# The naive method is our reference. It is a naive sequential model which loop through all the couples (u,v) referecing a value in the rating matrix, and updating the matrix P and the matrix Q, sequentially.
#
# It is therefore not optimal at all especially for the larger dimensions.
#
# We use this method as a benchmark.

# %%
class modelNaive:

    def __init__(self, ratingMatrix, latent_dim, learning_rate,
                 l_p, l_q):
        """
        Class attributes:
        -----------
            ratingMatrix: Matrix of the ratings
            latent_dim: latent dimension of p and q
            learning_rate: learning rate coefficient
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
            nbre_threads: number of threads available
        """
        self.ratingMatrix = ratingMatrix
        self.latent_dim = latent_dim
        self.learning_rate = learning_rate
        self.l_p = l_p
        self.l_q = l_q
        self.__parameters = self.__initialize_parameters()

        # id coef not null - Must have sparse.to_csr for the matrix
        self.id_x = ratingMatrix.nonzero()[0]
        self.id_y = ratingMatrix.nonzero()[1]
        
        # Track number of updates
        self.nb_updates = 0
        
    def __initialize_parameters(self):
        """
        Parameters:
        -----------
            latent_dim: latent dimension of p and q
            ratingMatrix: rating matrix
        Output:
        -----------
            p: P matrix with random parameters (user matrix)
            q: Q matrix with random parameters (item matrix)
        """
        p = np.random.rand(self.latent_dim, self.ratingMatrix.shape[0])/10
        q = np.random.rand(self.latent_dim, self.ratingMatrix.shape[1])/10
        
        r_hat_init = np.dot(np.transpose(p), q)

        return p, q, r_hat_init

    def updateDescente(self, u, v):
        """
        Parameters:
        -----------
            p: matrix with random parameters (user matrix)
            q: matrix with random parameters (item matrix)
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
        Output:
        -----------
            p_u: column u of p updated with the gradient descent
            q_v: column v of q updated with the gradient descent
        """
        # Non actualize parameters
        p_u = self.__parameters[0][:, u]
        q_v = self.__parameters[1][:, v]

        # Calcul de la descente de gradient
        e = self.ratingMatrix[u, v] - np.dot(np.transpose(p_u), q_v)
        p_u = p_u + self.learning_rate*(e*q_v - self.l_p*p_u)
        q_v = q_v + self.learning_rate*(e*p_u - self.l_q*q_v)

        # update de p et q
        self.__parameters[0][:, u], self.__parameters[1][:, v] = p_u, q_v
        
        # Nb updates
        self.nb_updates += 1

    def updatePQ(self):
        """
        Parameters:
        -----------
            p: matrix with random parameters (user matrix)
            q: matrix with random parameters (item matrix)
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
        Output:
        -----------
            p_u: column u of p updated with the gradient descent
            q_v: column v of q updated with the gradient descent
        """
        for u, v in zip(self.id_x, self.id_y):
            modelNaive.updateDescente(self, u, v)
            '''if timer > time_break:
                break'''

    def get_updated_matrix(self):
        """
        Output:
        -----------
            p: Matrix P (users)
            q: Matrix Q (items)
        """
        return self.__parameters

# %%
modeleNaive_ = modelNaive(A, latent_dim, learning_rate, l_p, l_q)

j = 0

start_time = time.time()

while rmse > stop_cond:

    start_temp = time.time()

    # Gradient descent
    #modeleNaive_.updatePQ(start_time, time_break)
    modeleNaive_.updatePQ()

    ''' # Print iter
    if j % print_iter == 0:
        print('----')
        print('Iteration', j, ' - ', time.time() - start_temp, 's per iteration')
    j += 1
    '''
    # stop condition for iterative method
    if time.time() - start_time > time_break:
        break
# Out:
# /Users/louisgiron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:67: RuntimeWarning: overflow encountered in multiply
# /Users/louisgiron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:66: RuntimeWarning: overflow encountered in multiply
# /Users/louisgiron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in subtract
# /Users/louisgiron/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in add

# %%
print("Execution time - itératif: %s secondes ----" % np.round((time.time() - start_time), 2))
# Out:
# Execution time - itératif: 945.47 secondes ----

# %% [markdown]
# #### Calcul du RMSE

# %%
# Get the updated p and q
p = modeleNaive_.get_updated_matrix()[0]
q = modeleNaive_.get_updated_matrix()[1]

# %%
R_hat_init = modeleNaive_.get_updated_matrix()[2]
R_hat = np.dot(np.transpose(p), q)

# %%
rmse_init = RMSE(A, R_hat_init, id_x, id_y, nb_ratings)
print('-----')
print('Initial RMSE:', rmse_init)
print()
rmse = RMSE(A, R_hat, id_x, id_y, nb_ratings)
print('-----')
print('RMSE:', rmse)
print()
print('-----')
print('Gain:', rmse_init - rmse)
# Out:
# -----
# Initial RMSE 3.704220606915771
#
# -----
# RMSE nan
#
# -----
# Gain: nan

# %% [markdown]
# ## II - HogWild Algorithm

# %% [markdown]
# HogWild algorithm assumes that the rating matrix is highly sparse and deduces that for two randomly sampled ratings, the gradient descent are likely to be independent.

# %%
class modelHogWild:

    def __init__(self, ratingMatrix, latent_dim, learning_rate,
                 l_p, l_q, nb_threads):
        """
        Class attributes:
        -----------
            ratingMatrix: Matrix of the ratings
            latent_dim: latent dimension of p and q
            learning_rate: learning rate coefficient
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
        """
        self.ratingMatrix = ratingMatrix
        self.latent_dim = latent_dim
        self.learning_rate = learning_rate
        self.l_p = l_p
        self.l_q = l_q
        self.nb_process = nb_process

        # Computed attributes
        self.__parameters = self.__initialize_parameters()

        # id coef not null - Must have sparse.to_csr for the matrix
        self.id_x = ratingMatrix.nonzero()[0]
        self.id_y = ratingMatrix.nonzero()[1]
        
        # Track number of updates
        self.nb_updates = 0

    def __initialize_parameters(self):
        """
        Parameters:
        -----------
            latent_dim: latent dimension of p and q
            ratingMatrix: rating matrix
        Output:
        -----------
            p: P matrix with random parameters (user matrix)
            q: Q matrix with random parameters (item matrix)
        """
        p = np.random.rand(self.latent_dim, self.ratingMatrix.shape[0])/10
        q = np.random.rand(self.latent_dim, self.ratingMatrix.shape[1])/10
        
        r_hat_init = np.dot(np.transpose(p), q)

        return p, q, r_hat_init
    
    # Implementation of the first method - Multi-threading

    def updateDescente_multithreading(self, u, v):
        """
        Parameters:
        -----------
            p: matrix with random parameters (user matrix)
            q: matrix with random parameters (item matrix)
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
        Output:
        -----------
            p_u: column u of p updated with the gradient descent
            q_v: column v of q updated with the gradient descent
        """
        # Non actualize parameters
        p_u = self.__parameters[0][:, u]
        q_v = self.__parameters[1][:, v]

        # Calcul de la descente de gradient
        e = self.ratingMatrix[u, v] - np.dot(np.transpose(p_u), q_v)
        p_u = p_u + self.learning_rate*(e*q_v - self.l_p*p_u)
        q_v = q_v + self.learning_rate*(e*p_u - self.l_q*q_v)

        # update de p et q
        self.__parameters[0][:, u], self.__parameters[1][:, v] = p_u, q_v
        
        # update Nb updates
        self.nb_updates += 1

    def multithreading(self):
        """
        Parameters:
        -----------
            p: matrix with random parameters (user matrix)
            q: matrix with random parameters (item matrix)
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
        Output:
        -----------
            p_u: column u of p updated with the gradient descent
            q_v: column v of q updated with the gradient descent
        """
        def chooseUV(id_x, id_y, nb_process):
            index_chosen = np.random.randint(0, len(id_x), nb_process)
            return id_x[index_chosen], id_y[index_chosen]

        res_ = chooseUV(self.id_x, self.id_y, self.nb_process)
        u_ = res_[0]
        v_ = res_[1]

        with ThreadPoolExecutor(max_workers=self.nb_process) as executor:
            executor.map(self.updateDescente_multithreading, u_, v_)
    
    # Implementation of the second method - Multi-processing
    
    def updateDescente_multiprocessing(self, tuple_uv_in, results):
        """
        Parameters:
        -----------
            p: matrix with random parameters (user matrix)
            q: matrix with random parameters (item matrix)
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
        Output:
        -----------
            p_u: column u of p updated with the gradient descent
            q_v: column v of q updated with the gradient descent
        """
        try:
            tuple_uv = tuple_uv_in.get()
        except Exception:
            return
        u_in = tuple_uv[0]
        v_in = tuple_uv[1]
        
        # Non actualize parameters
        p_u = self.__parameters[0][:, u_in]
        q_v = self.__parameters[1][:, v_in]

        # Calcul de la descente de gradient
        e = self.ratingMatrix[u_in, v_in] - np.dot(np.transpose(p_u), q_v)
        p_u = p_u + self.learning_rate*(e*q_v - self.l_p*p_u)
        q_v = q_v + self.learning_rate*(e*p_u - self.l_q*q_v)

        # Push p_u and q_v in the queue
        results.put([u_in, p_u, v_in, q_v])

        proc_name = multiprocessing.current_process().name
        # print( '%s: Index u : %s, Index v : %s' % (proc_name, u_in, v_in))
        
        # update Nb updates
        self.nb_updates += 1
        return

    def multiprocess(self):
        """
        Parameters:
        -----------
            p: matrix with random parameters (user matrix)
            q: matrix with random parameters (item matrix)
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
        Output:
        -----------
            p_u: column u of p updated with the gradient descent
            q_v: column v of q updated with the gradient descent
        """
        def chooseUV(id_x, id_y, nb_process):
            index_chosen = np.random.randint(0, len(id_x), nb_process)
            return [(id_x[y], id_y[y]) for y in index_chosen]

        tuple_uv_ = chooseUV(self.id_x, self.id_y, self.nb_process)

        tuple_uv_in = Queue()
        results = Queue()

        for i in range(self.nb_process):
            tuple_uv_in.put(tuple_uv_[i])

        jobs = [Process(target=self.updateDescente_multiprocessing,
                        args=(tuple_uv_in, results))
                for i in range(self.nb_process)]

        for j in jobs:
            j.start()
        
        for j in jobs:
            j.join()

        n = self.nb_process
        while (n):
            result = results.get()
            self.__parameters[0][:, result[0]] = result[1]
            self.__parameters[1][:, result[2]] = result[3]
            n -= 1

    def get_updated_matrix(self):
        """
        Output:
        -----------
            p: Matrix P (users)
            q: Matrix Q (items)
        """
        return self.__parameters

# %% [markdown]
# ### II - A - MultiThreading approach

# %%
modelHogWild_ = modelHogWild(A, latent_dim, learning_rate, l_p, l_q, nb_process)
j = 0
start_time = time.time()

while rmse > stop_cond:
    
    start_temp = time.time()

    # Gradient descent
    modelHogWild_.multithreading()

    '''# Print
    j += 1
    if j % print_iter == 0:
        print('-----')
        print('Iteration', j, ' - ', np.round(time.time() - start_temp, 2), 's per iteration')'''

    # stop condition for iterative method
    if time.time() - start_time > time_break:
        break

# %%
print("Execution time - MultiThreading: %s secondes ---" % np.round((time.time() - start_time), 2))
# Out:
# Execution time - MultiThreading: 0.01 secondes ---

# %% [markdown]
# #### Calcul du RMSE

# %%
# Get the updated p and q
p = modelHogWild_.get_updated_matrix()[0]
q = modelHogWild_.get_updated_matrix()[1]

# %%
R_hat_init = modelHogWild_.get_updated_matrix()[2]
R_hat = np.dot(np.transpose(p), q)

# %%
rmse_init = RMSE(A, R_hat_init, id_x, id_y, nb_ratings)
print('-----')
print('Initial RMSE', rmse_init)
print()
rmse = RMSE(A, R_hat, id_x, id_y, nb_ratings)
print('-----')
print('RMSE', rmse)
print()
print('-----')
print('Gain:', rmse_init - rmse)
# Out:
# -----
# Initial RMSE 3.7040307529955525
#
# -----
# RMSE 3.7040307529955525
#
# -----
# Gain: 0.0

# %% [markdown]
# The multithread approach on python does not fit our project. In fact, it corresponds to the iterative, i.e. the naive approach. Indeed, the GIL on python forces the algorithm to run on an only thread. Therefore, the gradient descent, here, is not parallelized but iterative.
# We must follow other methods, developed in the following parts.

# %% [markdown]
# ### II - B - MultiProcessing approach - Queue

# %%
modelHogWild_ = modelHogWild(A, latent_dim, learning_rate, l_p, l_q, nb_process)
j = 0
start_time = time.time()

while rmse > stop_cond:
    
    start_temp = time.time()

    # Gradient descent
    modelHogWild_.multiprocess()

    '''# Print
    j += 1
    if j % print_iter == 0:
        print('-----')
        print('Iteration', j, ' - ', np.round(time.time() - start_temp, 2), 's per iteration')'''
    # stop condition for iterative method
    if time.time() - start_time > time_break:
        break

# %%
print("Execution time - MultiProcessing, Queue approach: %s secondes ---" % np.round((time.time() - start_time), 2))
# Out:
# Execution time - MultiProcessing, Queue approach: 900.04 secondes ---

# %% [markdown]
# ##### Calcul du RMSE

# %%
# Get the updated p and q
p = modelHogWild_.get_updated_matrix()[0]
q = modelHogWild_.get_updated_matrix()[1]

# %%
R_hat_init = modelHogWild_.get_updated_matrix()[2]
R_hat = np.dot(np.transpose(p), q)

# %%
rmse_init = RMSE(A, R_hat_init, id_x, id_y, nb_ratings)
print('-----')
print('Initial RMSE', rmse_init)
print()
rmse = RMSE(A, R_hat, id_x, id_y, nb_ratings)
print('-----')
print('RMSE', rmse)
print()
print('-----')
print('Gain:', rmse_init - rmse)
# Out:
# -----
# Initial RMSE 3.7040778347081225
#
# -----
# RMSE 1.6700039728814609
#
# -----
# Gain: 2.034073861826662

# %% [markdown]
# ### II - D - Observations

# %% [markdown]
# - The multi-threading is a non-optimal approach. In fact, the GIL (Global Interpreter Lock) locks the access to multiple threads in parallel. Python wasn't designed considering that personal computers might have more than one core (shows you how old the language is), so the GIL is necessary because Python is not thread-safe and there is a globally enforced lock when accessing a Python object. Though not perfect, it's a pretty effective mechanism for memory management.
#
# - The Queue approach seems to be the most adapted approach. In fact, the implementation of the FSPG algorithm (later) includes a scheduler, therefore, an ordonnate management allowed with the queues. We will, thus, use the queue approach for the last algorithm, FSPG.

# %% [markdown]
# ## III - DSGD Algorithm

# %%
class modelDSGD:

    def __init__(self, ratingMatrix, latent_dim, learning_rate,
                 l_p, l_q, nb_process):
        """
        Class attributes:
        -----------
            ratingMatrix: Matrix of the ratings
            latent_dim: latent dimension of p and q
            learning_rate: learning rate coefficient
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
            nbre_threads: number of threads available
        """
        self.ratingMatrix = ratingMatrix
        self.latent_dim = latent_dim
        self.learning_rate = learning_rate
        self.l_p = l_p
        self.l_q = l_q
        self.nb_process = nb_process
        self.__parameters = self.__initialize_parameters()

        # id coef not null - Must have sparse.to_csr for the matrix
        self.id_x = ratingMatrix.nonzero()[0]
        self.id_y = ratingMatrix.nonzero()[1]
        
        # Track number of updates
        self.nb_updates = 0

    def Sequential_List_Treatment(self):
        """
        Parameters:
        -----------
            Nbre_threads : number of threads available
        Output:
        -----------
            Steps : list indicating at each step of one parallelisation,
            the submatrix that each thread should treat
        """
        Steps = []
        for k in range(self.nb_process):
            latent = {}
            for i in range(self.nb_process):
                j = (i+k) % self.nb_process
                latent["Thread" + str(i)] = [i, j]
            Steps.append(latent)
        return Steps

    def create_Index_Sub_Matrix(self):
        """
        Parameters:
        -----------
            R:Ratings Matrix
            nbre_threads: Number of available threads
        Output
        --------
            dic_row: Dictionnary indicating the available u for each sub matrix
            dic_cal: Dictionnary indicating the available v for each sub matrix
        """
        nrow, ncol = self.ratingMatrix.shape
        inter_row = nrow // self.nb_process
        inter_col = ncol // self.nb_process
        dic_row = {}
        dic_col = {}
        for i in range(self.nb_process-1):
            dic_row[i] = list(range(i*inter_row, (i+1)*inter_row))
            dic_col[i] = list(range(i*inter_col, (i+1)*inter_col))
        dic_row[i+1] = list(range((i+1)*inter_row, nrow))
        dic_col[i+1] = list(range((i+1)*inter_col, ncol))
        return dic_row, dic_col

    def grid_uv_generation(self, id_row, id_col):
        """
        Parameters:
        -----------
            id_row: row index of the submatrix
            id_col: col index of the submatrix
        Output:
        -----------
            u, v for the specific thread
        """
        # Id of the sub-block s
        (ids_block_row,
         ids_block_col) = modelDSGD.create_Index_Sub_Matrix(self)
        subblock = (ids_block_row[id_row], ids_block_col[id_col])

        couple_subblock = set([(i, j) for i, j in itls.product(subblock[0],
                                                               subblock[1])])
        # Intersection of the not null coefficient
        couple_uv = set([(i, j) for i, j in zip(self.id_x, self.id_y)])

        # Interesct
        return list(couple_subblock.intersection(couple_uv))

    def __initialize_parameters(self):
        """
        Parameters:
        -----------
            latent_dim: latent dimension of p and q
            ratingMatrix: rating matrix
        Output:
        -----------
            p: P matrix with random parameters (user matrix)
            q: Q matrix with random parameters (item matrix)
        """
        p = np.random.rand(self.latent_dim, self.ratingMatrix.shape[0])/10
        q = np.random.rand(self.latent_dim, self.ratingMatrix.shape[1])/10
        r_hat_init = np.dot(np.transpose(p), q)

        return p, q, r_hat_init

    # Implementation of the queue approach

    def updateDescente(self, tuple_uv, results):
        """
        Parameters:
        -----------
            p: matrix with random parameters (user matrix)
            q: matrix with random parameters (item matrix)
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
        Output:
        -----------
            p_u: column u of p updated with the gradient descent
            q_v: column v of q updated with the gradient descent
        """
        # Non actualize parameters
        p_u = self.__parameters[0][:, tuple_uv[0]]
        q_v = self.__parameters[1][:, tuple_uv[1]]

        # Calcul de la descente de gradient
        e = self.ratingMatrix[tuple_uv[0], tuple_uv[1]] - np.dot(np.transpose(p_u), q_v)
        p_u = p_u + self.learning_rate*(e*q_v - self.l_p*p_u)
        q_v = q_v + self.learning_rate*(e*p_u - self.l_q*q_v)

        # Push p_u and q_v in the queue
        results.put([tuple_uv[0], p_u, tuple_uv[1], q_v])
        
        proc_name = multiprocessing.current_process().name
        # print( '%s: Index u : %s, Index v : %s' % (proc_name, tuple_uv[0], tuple_uv[1]))
        
        # Update Nb updates
        self.nb_updates += 1
        return

    def multiprocess(self):
        """
        Parameters:
        -----------
            p: matrix with random parameters (user matrix)
            q: matrix with random parameters (item matrix)
            l_p: reguralization parameter for p_u
            l_q: reguralization parameter for q_v
        Output:
        -----------
            p_u: column u of p updated with the gradient descent
            q_v: column v of q updated with the gradient descent
        """
        def update_one_sub_matrix(blocks, results):
            try:
                block = blocks.get()
            except:
                return
            for tuple_uv in block:
                # Launch gradient descent
                modelDSGD.updateDescente(self, tuple_uv, results)

        # Pattern of matrix R
        patterns = modelDSGD.Sequential_List_Treatment(self)

        for pattern in patterns:
            # Define the empty queues
            blocks = Queue()
            results = Queue()
            
            count = 0

            sub_block = list(pattern.values())
            sub_block = [np.random.permutation(modelDSGD_.grid_uv_generation(y[0], y[1])) for y in sub_block]
            
            for sub in sub_block:
                blocks.put(sub)
            
            count=np.sum([len(a) for a in sub_block])

            jobs = [Process(target=update_one_sub_matrix,
                            args=(blocks, results))
                    for i in range(self.nb_process)]

            for j in jobs:
                j.start()
            
            for j in jobs:
                j.join(timeout=0)
                if j.is_alive():
                    print('Job is not finished')
                else:
                    print('Job is done')
                print('Successful join:', j.name)

            n = count
            while (n):
                result = results.get()
                self.__parameters[0][:, result[0]] = result[1]
                self.__parameters[1][:, result[2]] = result[3]
                n -= 1

    def get_updated_matrix(self):
        """
        Output:
        -----------
            p: Matrix P (users)
            q: Matrix Q (items)
        """
        return self.__parameters

# %%
modelDSGD_ = modelDSGD(A, latent_dim, learning_rate, l_p, l_q, nb_process)
j = 0
start_time = time.time()

while rmse > stop_cond:
    
    start_temp = time.time()

    # Gradient descent
    modelDSGD_.multiprocess()
    
    '''# Print
    j += 1
    if j % print_iter == 0:
        print('-----')
        print('Iteration', j, ' - ', np.round(time.time() - start_temp, 2), 's per iteration')'''

    # stop condition for iterative method
    if time.time() - start_time > time_break:
        break
# Out:
# Job is not finished
# Successful join: Process-208675
# Job is not finished
# Successful join: Process-208676
# Job is not finished
# Successful join: Process-208677
# Job is not finished
# Successful join: Process-208678
# Job is not finished
# Successful join: Process-208679
# Job is not finished
# Successful join: Process-208680
# Job is not finished
# Successful join: Process-208681
# Job is not finished
# Successful join: Process-208682
# Job is not finished
# Successful join: Process-208683
# Job is not finished
# Successful join: Process-208684
# Job is not finished
# Successful join: Process-208685
# Job is not finished
# Successful join: Process-208686
# Job is not finished
# Successful join: Process-208687
# Job is not finished
# Successful join: Process-208688
# Job is not finished
# Successful join: Process-208689
# Job is not finished
# Successful join: Process-208690
# Job is not finished
# Successful join: Process-208691
# Job is not finished
# Successful join: Process-208692
# Job is not finished
# Successful join: Process-208693
# Job is not finished
# Successful join: Process-208694
# Job is not finished
# Successful join: Process-208695
# Job is not finished
# Successful join: Process-208696
# Job is not finished
# Successful join: Process-208697
# Job is not finished
# Successful join: Process-208698
# Job is not finished
# Successful join: Process-208699
# Job is not finished
# Successful join: Process-208700
# Job is not finished
# Successful join: Process-208701
# Job is not finished
# Successful join: Process-208702
# Job is not finished
# Successful join: Process-208703
# Job is not finished
# Successful join: Process-208704
# Job is not finished
# Successful join: Process-208705
# Job is not finished
# Successful join: Process-208706
# Job is not finished
# Successful join: Process-208707
# Job is not finished
# Successful join: Process-208708
# Job is not finished
# Successful join: Process-208709
# Job is not finished
# Successful join: Process-208710
# Job is not finished
# Successful join: Process-208711
# Job is not finished
# Successful join: Process-208712
# Job is not finished
# Successful join: Process-208713
# Job is not finished
# Successful join: Process-208714
# Job is not finished
# Successful join: Process-208715
# Job is not finished
# Successful join: Process-208716
# Job is not finished
# Successful join: Process-208717
# Job is not finished
# Successful join: Process-208718
# Job is not finished
# Successful join: Process-208719
# Job is not finished
# Successful join: Process-208720
# Job is not finished
# Successful join: Process-208721
# Job is not finished
# Successful join: Process-208722
# Job is not finished
# Successful join: Process-208723
# Job is not finished
# Successful join: Process-208724
# Job is not finished
# Successful join: Process-208725
# Job is not finished
# Successful join: Process-208726
# Job is not finished
# Successful join: Process-208727
# Job is not finished
# Successful join: Process-208728
# Job is not finished
# Successful join: Process-208729
# Job is not finished
# Successful join: Process-208730
# Job is not finished
# Successful join: Process-208731
# Job is not finished
# Successful join: Process-208732
# Job is not finished
# Successful join: Process-208733
# Job is not finished
# Successful join: Process-208734
# Job is not finished
# Successful join: Process-208735
# Job is not finished
# Successful join: Process-208736
# Job is not finished
# Successful join: Process-208737
# Job is not finished
# Successful join: Process-208738
# Job is not finished
# Successful join: Process-208739
# Job is not finished
# Successful join: Process-208740
# Job is not finished
# Successful join: Process-208741
# Job is not finished
# Successful join: Process-208742
# Job is not finished
# Successful join: Process-208743
# Job is not finished
# Successful join: Process-208744
# Job is not finished
# Successful join: Process-208745
# Job is not finished
# Successful join: Process-208746
# Job is not finished
# Successful join: Process-208747
# Job is not finished
# Successful join: Process-208748
# Job is not finished
# Successful join: Process-208749
# Job is not finished
# Successful join: Process-208750
# Job is not finished
# Successful join: Process-208751
# Job is not finished
# Successful join: Process-208752
# Job is not finished
# Successful join: Process-208753
# Job is not finished
# Successful join: Process-208754
# Job is not finished
# Successful join: Process-208755
# Job is not finished
# Successful join: Process-208756
# Job is not finished
# Successful join: Process-208757
# Job is not finished
# Successful join: Process-208758
# Job is not finished
# Successful join: Process-208759
# Job is not finished
# Successful join: Process-208760
# Job is not finished
# Successful join: Process-208761
# Job is not finished
# Successful join: Process-208762
# Job is not finished
# Successful join: Process-208763
# Job is not finished
# Successful join: Process-208764
# Job is not finished
# Successful join: Process-208765
# Job is not finished
# Successful join: Process-208766
# Job is not finished
# Successful join: Process-208767
# Job is not finished
# Successful join: Process-208768
# Job is not finished
# Successful join: Process-208769
# Job is not finished
# Successful join: Process-208770
# Job is not finished
# Successful join: Process-208771
# Job is not finished
# Successful join: Process-208772
# Job is not finished
# Successful join: Process-208773
# Job is not finished
# Successful join: Process-208774
# Job is not finished
# Successful join: Process-208775
# Job is not finished
# Successful join: Process-208776
# Job is not finished
# Successful join: Process-208777
# Job is not finished
# Successful join: Process-208778
# Job is not finished
# Successful join: Process-208779
# Job is not finished
# Successful join: Process-208780
# Job is not finished
# Successful join: Process-208781
# Job is not finished
# Successful join: Process-208782
# Job is not finished
# Successful join: Process-208783
# Job is not finished
# Successful join: Process-208784
# Job is not finished
# Successful join: Process-208785
# Job is not finished
# Successful join: Process-208786
# Job is not finished
# Successful join: Process-208787
# Job is not finished
# Successful join: Process-208788
# Job is not finished
# Successful join: Process-208789
# Job is not finished
# Successful join: Process-208790
# Job is not finished
# Successful join: Process-208791
# Job is not finished
# Successful join: Process-208792
# Job is not finished
# Successful join: Process-208793
# Job is not finished
# Successful join: Process-208794
# Job is not finished
# Successful join: Process-208795
# Job is not finished
# Successful join: Process-208796
# Job is not finished
# Successful join: Process-208797
# Job is not finished
# Successful join: Process-208798
# Job is not finished
# Successful join: Process-208799
# Job is not finished
# Successful join: Process-208800
# Job is not finished
# Successful join: Process-208801
# Job is not finished
# Successful join: Process-208802
# Job is not finished
# Successful join: Process-208803
# Job is not finished
# Successful join: Process-208804
# Job is not finished
# Successful join: Process-208805
# Job is not finished
# Successful join: Process-208806
# Job is not finished
# Successful join: Process-208807
# Job is not finished
# Successful join: Process-208808
# Job is not finished
# Successful join: Process-208809
# Job is not finished
# Successful join: Process-208810
# Job is not finished
# Successful join: Process-208811
# Job is not finished
# Successful join: Process-208812
# Job is not finished
# Successful join: Process-208813
# Job is not finished
# Successful join: Process-208814
# Job is not finished
# Successful join: Process-208815
# Job is not finished
# Successful join: Process-208816
# Job is not finished
# Successful join: Process-208817
# Job is not finished
# Successful join: Process-208818
# Job is not finished
# Successful join: Process-208819
# Job is not finished
# Successful join: Process-208820
# Job is not finished
# Successful join: Process-208821
# Job is not finished
# Successful join: Process-208822
# Job is not finished
# Successful join: Process-208823
# Job is not finished
# Successful join: Process-208824
# Job is not finished
# Successful join: Process-208825
# Job is not finished
# Successful join: Process-208826
# Job is not finished
# Successful join: Process-208827
# Job is not finished
# Successful join: Process-208828
# Job is not finished
# Successful join: Process-208829
# Job is not finished
# Successful join: Process-208830
# Job is not finished
# Successful join: Process-208831
# Job is not finished
# Successful join: Process-208832
# Job is not finished
# Successful join: Process-208833
# Job is not finished
# Successful join: Process-208834
# Job is not finished
# Successful join: Process-208835
# Job is not finished
# Successful join: Process-208836
# Job is not finished
# Successful join: Process-208837
# Job is not finished
# Successful join: Process-208838
# Job is not finished
# Successful join: Process-208839
# Job is not finished
# Successful join: Process-208840
# Job is not finished
# Successful join: Process-208841
# Job is not finished
# Successful join: Process-208842
# Job is not finished
# Successful join: Process-208843
# Job is not finished
# Successful join: Process-208844
# Job is not finished
# Successful join: Process-208845
# Job is not finished
# Successful join: Process-208846
# Job is not finished
# Successful join: Process-208847
# Job is not finished
# Successful join: Process-208848
# Job is not finished
# Successful join: Process-208849
# Job is not finished
# Successful join: Process-208850
# Job is not finished
# Successful join: Process-208851
# Job is not finished
# Successful join: Process-208852
# Job is not finished
# Successful join: Process-208853
# Job is not finished
# Successful join: Process-208854
# Job is not finished
# Successful join: Process-208855
# Job is not finished
# Successful join: Process-208856
# Job is not finished
# Successful join: Process-208857
# Job is not finished
# Successful join: Process-208858
# Job is not finished
# Successful join: Process-208859
# Job is not finished
# Successful join: Process-208860
# Job is not finished
# Successful join: Process-208861
# Job is not finished
# Successful join: Process-208862
# Job is not finished
# Successful join: Process-208863
# Job is not finished
# Successful join: Process-208864
# Job is not finished
# Successful join: Process-208865
# Job is not finished
# Successful join: Process-208866
# Job is not finished
# Successful join: Process-208867
# Job is not finished
# Successful join: Process-208868
# Job is not finished
# Successful join: Process-208869
# Job is not finished
# Successful join: Process-208870
# Job is not finished
# Successful join: Process-208871
# Job is not finished
# Successful join: Process-208872
# Job is not finished
# Successful join: Process-208873
# Job is not finished
# Successful join: Process-208874
# Job is not finished
# Successful join: Process-208875
# Job is not finished
# Successful join: Process-208876
# Job is not finished
# Successful join: Process-208877
# Job is not finished
# Successful join: Process-208878
# Job is not finished
# Successful join: Process-208879
# Job is not finished
# Successful join: Process-208880
# Job is not finished
# Successful join: Process-208881
# Job is not finished
# Successful join: Process-208882
# Job is not finished
# Successful join: Process-208883
# Job is not finished
# Successful join: Process-208884
# Job is not finished
# Successful join: Process-208885
# Job is not finished
# Successful join: Process-208886
# Job is not finished
# Successful join: Process-208887
# Job is not finished
# Successful join: Process-208888
# Job is not finished
# Successful join: Process-208889
# Job is not finished
# Successful join: Process-208890
# Job is not finished
# Successful join: Process-208891
# Job is not finished
# Successful join: Process-208892
# Job is not finished
# Successful join: Process-208893
# Job is not finished
# Successful join: Process-208894
# Job is not finished
# Successful join: Process-208895
# Job is not finished
# Successful join: Process-208896
# Job is not finished
# Successful join: Process-208897
# Job is not finished
# Successful join: Process-208898
# Job is not finished
# Successful join: Process-208899
# Job is not finished
# Successful join: Process-208900
# Job is not finished
# Successful join: Process-208901
# Job is not finished
# Successful join: Process-208902
# Job is not finished
# Successful join: Process-208903
# Job is not finished
# Successful join: Process-208904
# Job is not finished
# Successful join: Process-208905
# Job is not finished
# Successful join: Process-208906
# Job is not finished
# Successful join: Process-208907
# Job is not finished
# Successful join: Process-208908
# Job is not finished
# Successful join: Process-208909
# Job is not finished
# Successful join: Process-208910
# Job is not finished
# Successful join: Process-208911
# Job is not finished
# Successful join: Process-208912
# Job is not finished
# Successful join: Process-208913
# Job is not finished
# Successful join: Process-208914
# Job is not finished
# Successful join: Process-208915
# Job is not finished
# Successful join: Process-208916
# Job is not finished
# Successful join: Process-208917
# Job is not finished
# Successful join: Process-208918
# Job is not finished
# Successful join: Process-208919
# Job is not finished
# Successful join: Process-208920
# Job is not finished
# Successful join: Process-208921
# Job is not finished
# Successful join: Process-208922
# Job is not finished
# Successful join: Process-208923
# Job is not finished
# Successful join: Process-208924
# Job is not finished
# Successful join: Process-208925
# Job is not finished
# Successful join: Process-208926
# Job is not finished
# Successful join: Process-208927
# Job is not finished
# Successful join: Process-208928
# Job is not finished
# Successful join: Process-208929
# Job is not finished
# Successful join: Process-208930
# Job is not finished
# Successful join: Process-208931
# Job is not finished
# Successful join: Process-208932
# Job is not finished
# Successful join: Process-208933
# Job is not finished
# Successful join: Process-208934
# Job is not finished
# Successful join: Process-208935
# Job is not finished
# Successful join: Process-208936
# Job is not finished
# Successful join: Process-208937
# Job is not finished
# Successful join: Process-208938
# Job is not finished
# Successful join: Process-208939
# Job is not finished
# Successful join: Process-208940
# Job is not finished
# Successful join: Process-208941
# Job is not finished
# Successful join: Process-208942
# Job is not finished
# Successful join: Process-208943
# Job is not finished
# Successful join: Process-208944
# Job is not finished
# Successful join: Process-208945
# Job is not finished
# Successful join: Process-208946
# Job is not finished
# Successful join: Process-208947
# Job is not finished
# Successful join: Process-208948
# Job is not finished
# Successful join: Process-208949
# Job is not finished
# Successful join: Process-208950
# Job is not finished
# Successful join: Process-208951
# Job is not finished
# Successful join: Process-208952
# Job is not finished
# Successful join: Process-208953
# Job is not finished
# Successful join: Process-208954
# Job is not finished
# Successful join: Process-208955
# Job is not finished
# Successful join: Process-208956
# Job is not finished
# Successful join: Process-208957
# Job is not finished
# Successful join: Process-208958
# Job is not finished
# Successful join: Process-208959
# Job is not finished
# Successful join: Process-208960
# Job is not finished
# Successful join: Process-208961
# Job is not finished
# Successful join: Process-208962
# Job is not finished
# Successful join: Process-208963
# Job is not finished
# Successful join: Process-208964
# Job is not finished
# Successful join: Process-208965
# Job is not finished
# Successful join: Process-208966
# Job is not finished
# Successful join: Process-208967
# Job is not finished
# Successful join: Process-208968
# Job is not finished
# Successful join: Process-208969
# Job is not finished
# Successful join: Process-208970
# Job is not finished
# Successful join: Process-208971
# Job is not finished
# Successful join: Process-208972
# Job is not finished
# Successful join: Process-208973
# Job is not finished
# Successful join: Process-208974
# Job is not finished
# Successful join: Process-208975
# Job is not finished
# Successful join: Process-208976
# Job is not finished
# Successful join: Process-208977
# Job is not finished
# Successful join: Process-208978
# Job is not finished
# Successful join: Process-208979
# Job is not finished
# Successful join: Process-208980
# Job is not finished
# Successful join: Process-208981
# Job is not finished
# Successful join: Process-208982
# Job is not finished
# Successful join: Process-208983
# Job is not finished
# Successful join: Process-208984
# Job is not finished
# Successful join: Process-208985
# Job is not finished
# Successful join: Process-208986
# Job is not finished
# Successful join: Process-208987
# Job is not finished
# Successful join: Process-208988
# Job is not finished
# Successful join: Process-208989
# Job is not finished
# Successful join: Process-208990
# Job is not finished
# Successful join: Process-208991
# Job is not finished
# Successful join: Process-208992
# Job is not finished
# Successful join: Process-208993
# Job is not finished
# Successful join: Process-208994
# Job is not finished
# Successful join: Process-208995
# Job is not finished
# Successful join: Process-208996
# Job is not finished
# Successful join: Process-208997
# Job is not finished
# Successful join: Process-208998
# Job is not finished
# Successful join: Process-208999
# Job is not finished
# Successful join: Process-209000
# Job is not finished
# Successful join: Process-209001
# Job is not finished
# Successful join: Process-209002
# Job is not finished
# Successful join: Process-209003
# Job is not finished
# Successful join: Process-209004
# Job is not finished
# Successful join: Process-209005
# Job is not finished
# Successful join: Process-209006
# Job is not finished
# Successful join: Process-209007
# Job is not finished
# Successful join: Process-209008
# Job is not finished
# Successful join: Process-209009
# Job is not finished
# Successful join: Process-209010
# Job is not finished
# Successful join: Process-209011
# Job is not finished
# Successful join: Process-209012
# Job is not finished
# Successful join: Process-209013
# Job is not finished
# Successful join: Process-209014
# Job is not finished
# Successful join: Process-209015
# Job is not finished
# Successful join: Process-209016
# Job is not finished
# Successful join: Process-209017
# Job is not finished
# Successful join: Process-209018
# Job is not finished
# Successful join: Process-209019
# Job is not finished
# Successful join: Process-209020
# Job is not finished
# Successful join: Process-209021
# Job is not finished
# Successful join: Process-209022
# Job is not finished
# Successful join: Process-209023
# Job is not finished
# Successful join: Process-209024
# Job is not finished
# Successful join: Process-209025
# Job is not finished
# Successful join: Process-209026
# Job is not finished
# Successful join: Process-209027
# Job is not finished
# Successful join: Process-209028
# Job is not finished
# Successful join: Process-209029
# Job is not finished
# Successful join: Process-209030
# Job is not finished
# Successful join: Process-209031
# Job is not finished
# Successful join: Process-209032
# Job is not finished
# Successful join: Process-209033
# Job is not finished
# Successful join: Process-209034
# Job is not finished
# Successful join: Process-209035
# Job is not finished
# Successful join: Process-209036
# Job is not finished
# Successful join: Process-209037
# Job is not finished
# Successful join: Process-209038
# Job is not finished
# Successful join: Process-209039
# Job is not finished
# Successful join: Process-209040
# Job is not finished
# Successful join: Process-209041
# Job is not finished
# Successful join: Process-209042
# Job is not finished
# Successful join: Process-209043
# Job is not finished
# Successful join: Process-209044
# Job is not finished
# Successful join: Process-209045
# Job is not finished
# Successful join: Process-209046
# Job is not finished
# Successful join: Process-209047
# Job is not finished
# Successful join: Process-209048
# Job is not finished
# Successful join: Process-209049
# Job is not finished
# Successful join: Process-209050
# Job is not finished
# Successful join: Process-209051
# Job is not finished
# Successful join: Process-209052
# Job is not finished
# Successful join: Process-209053
# Job is not finished
# Successful join: Process-209054
# Job is not finished
# Successful join: Process-209055
# Job is not finished
# Successful join: Process-209056
# Job is not finished
# Successful join: Process-209057
# Job is not finished
# Successful join: Process-209058
# Job is not finished
# Successful join: Process-209059
# Job is not finished
# Successful join: Process-209060
# Job is not finished
# Successful join: Process-209061
# Job is not finished
# Successful join: Process-209062
# Job is not finished
# Successful join: Process-209063
# Job is not finished
# Successful join: Process-209064
# Job is not finished
# Successful join: Process-209065
# Job is not finished
# Successful join: Process-209066
# Job is not finished
# Successful join: Process-209067
# Job is not finished
# Successful join: Process-209068
# Job is not finished
# Successful join: Process-209069
# Job is not finished
# Successful join: Process-209070
# Job is not finished
# Successful join: Process-209071
# Job is not finished
# Successful join: Process-209072
# Job is not finished
# Successful join: Process-209073
# Job is not finished
# Successful join: Process-209074
# Job is not finished
# Successful join: Process-209075
# Job is not finished
# Successful join: Process-209076
# Job is not finished
# Successful join: Process-209077
# Job is not finished
# Successful join: Process-209078
# Job is not finished
# Successful join: Process-209079
# Job is not finished
# Successful join: Process-209080
# Job is not finished
# Successful join: Process-209081
# Job is not finished
# Successful join: Process-209082
# Job is not finished
# Successful join: Process-209083
# Job is not finished
# Successful join: Process-209084
# Job is not finished
# Successful join: Process-209085
# Job is not finished
# Successful join: Process-209086
# Job is not finished
# Successful join: Process-209087
# Job is not finished
# Successful join: Process-209088
# Job is not finished
# Successful join: Process-209089
# Job is not finished
# Successful join: Process-209090
# Job is not finished
# Successful join: Process-209091
# Job is not finished
# Successful join: Process-209092
# Job is not finished
# Successful join: Process-209093
# Job is not finished
# Successful join: Process-209094
# Job is not finished
# Successful join: Process-209095
# Job is not finished
# Successful join: Process-209096
# Job is not finished
# Successful join: Process-209097
# Job is not finished
# Successful join: Process-209098
# Job is not finished
# Successful join: Process-209099
# Job is not finished
# Successful join: Process-209100
# Job is not finished
# Successful join: Process-209101
# Job is not finished
# Successful join: Process-209102
# Job is not finished
# Successful join: Process-209103
# Job is not finished
# Successful join: Process-209104
# Job is not finished
# Successful join: Process-209105
# Job is not finished
# Successful join: Process-209106
# Job is not finished
# Successful join: Process-209107
# Job is not finished
# Successful join: Process-209108
# Job is not finished
# Successful join: Process-209109
# Job is not finished
# Successful join: Process-209110
# Job is not finished
# Successful join: Process-209111
# Job is not finished
# Successful join: Process-209112
# Job is not finished
# Successful join: Process-209113
# Job is not finished
# Successful join: Process-209114
# Job is not finished
# Successful join: Process-209115
# Job is not finished
# Successful join: Process-209116
# Job is not finished
# Successful join: Process-209117
# Job is not finished
# Successful join: Process-209118
# Job is not finished
# Successful join: Process-209119
# Job is not finished
# Successful join: Process-209120
# Job is not finished
# Successful join: Process-209121
# Job is not finished
# Successful join: Process-209122
# Job is not finished
# Successful join: Process-209123
# Job is not finished
# Successful join: Process-209124
# Job is not finished
# Successful join: Process-209125
# Job is not finished
# Successful join: Process-209126
# Job is not finished
# Successful join: Process-209127
# Job is not finished
# Successful join: Process-209128
# Job is not finished
# Successful join: Process-209129
# Job is not finished
# Successful join: Process-209130
# Job is not finished
# Successful join: Process-209131
# Job is not finished
# Successful join: Process-209132
# Job is not finished
# Successful join: Process-209133
# Job is not finished
# Successful join: Process-209134
# Job is not finished
# Successful join: Process-209135
# Job is not finished
# Successful join: Process-209136
# Job is not finished
# Successful join: Process-209137
# Job is not finished
# Successful join: Process-209138
# Job is not finished
# Successful join: Process-209139
# Job is not finished
# Successful join: Process-209140
# Job is not finished
# Successful join: Process-209141
# Job is not finished
# Successful join: Process-209142
# Job is not finished
# Successful join: Process-209143
# Job is not finished
# Successful join: Process-209144
# Job is not finished
# Successful join: Process-209145
# Job is not finished
# Successful join: Process-209146
# Job is not finished
# Successful join: Process-209147
# Job is not finished
# Successful join: Process-209148
# Job is not finished
# Successful join: Process-209149
# Job is not finished
# Successful join: Process-209150
# Job is not finished
# Successful join: Process-209151
# Job is not finished
# Successful join: Process-209152
# Job is not finished
# Successful join: Process-209153
# Job is not finished
# Successful join: Process-209154
# Job is not finished
# Successful join: Process-209155
# Job is not finished
# Successful join: Process-209156
# Job is not finished
# Successful join: Process-209157
# Job is not finished
# Successful join: Process-209158
# Job is not finished
# Successful join: Process-209159
# Job is not finished
# Successful join: Process-209160
# Job is not finished
# Successful join: Process-209161
# Job is not finished
# Successful join: Process-209162
# Job is not finished
# Successful join: Process-209163
# Job is not finished
# Successful join: Process-209164
# Job is not finished
# Successful join: Process-209165
# Job is not finished
# Successful join: Process-209166
# Job is not finished
# Successful join: Process-209167
# Job is not finished
# Successful join: Process-209168
# Job is not finished
# Successful join: Process-209169
# Job is not finished
# Successful join: Process-209170
# Job is not finished
# Successful join: Process-209171
# Job is not finished
# Successful join: Process-209172
# Job is not finished
# Successful join: Process-209173
# Job is not finished
# Successful join: Process-209174
# Job is not finished
# Successful join: Process-209175
# Job is not finished
# Successful join: Process-209176
# Job is not finished
# Successful join: Process-209177
# Job is not finished
# Successful join: Process-209178
# Job is not finished
# Successful join: Process-209179
# Job is not finished
# Successful join: Process-209180
# Job is not finished
# Successful join: Process-209181
# Job is not finished
# Successful join: Process-209182
# Job is not finished
# Successful join: Process-209183
# Job is not finished
# Successful join: Process-209184
# Job is not finished
# Successful join: Process-209185
# Job is not finished
# Successful join: Process-209186
# Job is not finished
# Successful join: Process-209187
# Job is not finished
# Successful join: Process-209188
# Job is not finished
# Successful join: Process-209189
# Job is not finished
# Successful join: Process-209190
# Job is not finished
# Successful join: Process-209191
# Job is not finished
# Successful join: Process-209192
# Job is not finished
# Successful join: Process-209193
# Job is not finished
# Successful join: Process-209194
# Job is not finished
# Successful join: Process-209195
# Job is not finished
# Successful join: Process-209196
# Job is not finished
# Successful join: Process-209197
# Job is not finished
# Successful join: Process-209198
# Job is not finished
# Successful join: Process-209199
# Job is not finished
# Successful join: Process-209200
# Job is not finished
# Successful join: Process-209201
# Job is not finished
# Successful join: Process-209202
# Job is not finished
# Successful join: Process-209203
# Job is not finished
# Successful join: Process-209204
# Job is not finished
# Successful join: Process-209205
# Job is not finished
# Successful join: Process-209206
# Job is not finished
# Successful join: Process-209207
# Job is not finished
# Successful join: Process-209208
# Job is not finished
# Successful join: Process-209209
# Job is not finished
# Successful join: Process-209210
# Job is not finished
# Successful join: Process-209211
# Job is not finished
# Successful join: Process-209212
# Job is not finished
# Successful join: Process-209213
# Job is not finished
# Successful join: Process-209214
# Job is not finished
# Successful join: Process-209215
# Job is not finished
# Successful join: Process-209216
# Job is not finished
# Successful join: Process-209217
# Job is not finished
# Successful join: Process-209218
# Job is not finished
# Successful join: Process-209219
# Job is not finished
# Successful join: Process-209220
# Job is not finished
# Successful join: Process-209221
# Job is not finished
# Successful join: Process-209222
# Job is not finished
# Successful join: Process-209223
# Job is not finished
# Successful join: Process-209224
# Job is not finished
# Successful join: Process-209225
# Job is not finished
# Successful join: Process-209226
# Job is not finished
# Successful join: Process-209227
# Job is not finished
# Successful join: Process-209228
# Job is not finished
# Successful join: Process-209229
# Job is not finished
# Successful join: Process-209230
# Job is not finished
# Successful join: Process-209231
# Job is not finished
# Successful join: Process-209232
# Job is not finished
# Successful join: Process-209233
# Job is not finished
# Successful join: Process-209234
# Job is not finished
# Successful join: Process-209235
# Job is not finished
# Successful join: Process-209236
# Job is not finished
# Successful join: Process-209237
# Job is not finished
# Successful join: Process-209238
# Job is not finished
# Successful join: Process-209239
# Job is not finished
# Successful join: Process-209240
# Job is not finished
# Successful join: Process-209241
# Job is not finished
# Successful join: Process-209242
# Job is not finished
# Successful join: Process-209243
# Job is not finished
# Successful join: Process-209244
# Job is not finished
# Successful join: Process-209245
# Job is not finished
# Successful join: Process-209246
# Job is not finished
# Successful join: Process-209247
# Job is not finished
# Successful join: Process-209248
# Job is not finished
# Successful join: Process-209249
# Job is not finished
# Successful join: Process-209250
# Job is not finished
# Successful join: Process-209251
# Job is not finished
# Successful join: Process-209252
# Job is not finished
# Successful join: Process-209253
# Job is not finished
# Successful join: Process-209254
# Job is not finished
# Successful join: Process-209255
# Job is not finished
# Successful join: Process-209256
# Job is not finished
# Successful join: Process-209257
# Job is not finished
# Successful join: Process-209258
# Job is not finished
# Successful join: Process-209259
# Job is not finished
# Successful join: Process-209260
# Job is not finished
# Successful join: Process-209261
# Job is not finished
# Successful join: Process-209262
# Job is not finished
# Successful join: Process-209263
# Job is not finished
# Successful join: Process-209264
# Job is not finished
# Successful join: Process-209265
# Job is not finished
# Successful join: Process-209266
# Job is not finished
# Successful join: Process-209267
# Job is not finished
# Successful join: Process-209268
# Job is not finished
# Successful join: Process-209269
# Job is not finished
# Successful join: Process-209270
# Job is not finished
# Successful join: Process-209271
# Job is not finished
# Successful join: Process-209272
# Job is not finished
# Successful join: Process-209273
# Job is not finished
# Successful join: Process-209274
# Job is not finished
# Successful join: Process-209275
# Job is not finished
# Successful join: Process-209276
# Job is not finished
# Successful join: Process-209277
# Job is not finished
# Successful join: Process-209278
# Job is not finished
# Successful join: Process-209279
# Job is not finished
# Successful join: Process-209280
# Job is not finished
# Successful join: Process-209281
# Job is not finished
# Successful join: Process-209282
# Job is not finished
# Successful join: Process-209283
# Job is not finished
# Successful join: Process-209284
# Job is not finished
# Successful join: Process-209285
# Job is not finished
# Successful join: Process-209286
# Job is not finished
# Successful join: Process-209287
# Job is not finished
# Successful join: Process-209288
# Job is not finished
# Successful join: Process-209289
# Job is not finished
# Successful join: Process-209290
# Job is not finished
# Successful join: Process-209291
# Job is not finished
# Successful join: Process-209292
# Job is not finished
# Successful join: Process-209293
# Job is not finished
# Successful join: Process-209294
# Job is not finished
# Successful join: Process-209295
# Job is not finished
# Successful join: Process-209296
# Job is not finished
# Successful join: Process-209297
# Job is not finished
# Successful join: Process-209298
# Job is not finished
# Successful join: Process-209299
# Job is not finished
# Successful join: Process-209300
# Job is not finished
# Successful join: Process-209301
# Job is not finished
# Successful join: Process-209302
# Job is not finished
# Successful join: Process-209303
# Job is not finished
# Successful join: Process-209304
# Job is not finished
# Successful join: Process-209305
# Job is not finished
# Successful join: Process-209306
# Job is not finished
# Successful join: Process-209307
# Job is not finished
# Successful join: Process-209308
# Job is not finished
# Successful join: Process-209309
# Job is not finished
# Successful join: Process-209310
# Job is not finished
# Successful join: Process-209311
# Job is not finished
# Successful join: Process-209312
# Job is not finished
# Successful join: Process-209313
# Job is not finished
# Successful join: Process-209314
# Job is not finished
# Successful join: Process-209315
# Job is not finished
# Successful join: Process-209316
# Job is not finished
# Successful join: Process-209317
# Job is not finished
# Successful join: Process-209318
# Job is not finished
# Successful join: Process-209319
# Job is not finished
# Successful join: Process-209320
# Job is not finished
# Successful join: Process-209321
# Job is not finished
# Successful join: Process-209322
# Job is not finished
# Successful join: Process-209323
# Job is not finished
# Successful join: Process-209324
# Job is not finished
# Successful join: Process-209325
# Job is not finished
# Successful join: Process-209326
# Job is not finished
# Successful join: Process-209327
# Job is not finished
# Successful join: Process-209328
# Job is not finished
# Successful join: Process-209329
# Job is not finished
# Successful join: Process-209330
# Job is not finished
# Successful join: Process-209331
# Job is not finished
# Successful join: Process-209332
# Job is not finished
# Successful join: Process-209333
# Job is not finished
# Successful join: Process-209334
# Job is not finished
# Successful join: Process-209335
# Job is not finished
# Successful join: Process-209336
# Job is not finished
# Successful join: Process-209337
# Job is not finished
# Successful join: Process-209338
# Job is not finished
# Successful join: Process-209339
# Job is not finished
# Successful join: Process-209340
# Job is not finished
# Successful join: Process-209341
# Job is not finished
# Successful join: Process-209342
# Job is not finished
# Successful join: Process-209343
# Job is not finished
# Successful join: Process-209344
# Job is not finished
# Successful join: Process-209345
# Job is not finished
# Successful join: Process-209346
# Job is not finished
# Successful join: Process-209347
# Job is not finished
# Successful join: Process-209348
# Job is not finished
# Successful join: Process-209349
# Job is not finished
# Successful join: Process-209350
# Job is not finished
# Successful join: Process-209351
# Job is not finished
# Successful join: Process-209352
# Job is not finished
# Successful join: Process-209353
# Job is not finished
# Successful join: Process-209354
# Job is not finished
# Successful join: Process-209355
# Job is not finished
# Successful join: Process-209356
# Job is not finished
# Successful join: Process-209357
# Job is not finished
# Successful join: Process-209358
# Job is not finished
# Successful join: Process-209359
# Job is not finished
# Successful join: Process-209360
# Job is not finished
# Successful join: Process-209361
# Job is not finished
# Successful join: Process-209362
# Job is not finished
# Successful join: Process-209363
# Job is not finished
# Successful join: Process-209364
# Job is not finished
# Successful join: Process-209365
# Job is not finished
# Successful join: Process-209366
# Job is not finished
# Successful join: Process-209367
# Job is not finished
# Successful join: Process-209368
# Job is not finished
# Successful join: Process-209369
# Job is not finished
# Successful join: Process-209370
# Job is not finished
# Successful join: Process-209371
# Job is not finished
# Successful join: Process-209372
# Job is not finished
# Successful join: Process-209373
# Job is not finished
# Successful join: Process-209374
# Job is not finished
# Successful join: Process-209375
# Job is not finished
# Successful join: Process-209376
# Job is not finished
# Successful join: Process-209377
# Job is not finished
# Successful join: Process-209378
# Job is not finished
# Successful join: Process-209379
# Job is not finished
# Successful join: Process-209380
# Job is not finished
# Successful join: Process-209381
# Job is not finished
# Successful join: Process-209382
# Job is not finished
# Successful join: Process-209383
# Job is not finished
# Successful join: Process-209384
# Job is not finished
# Successful join: Process-209385
# Job is not finished
# Successful join: Process-209386
# Job is not finished
# Successful join: Process-209387
# Job is not finished
# Successful join: Process-209388
# Job is not finished
# Successful join: Process-209389
# Job is not finished
# Successful join: Process-209390
# Job is not finished
# Successful join: Process-209391
# Job is not finished
# Successful join: Process-209392
# Job is not finished
# Successful join: Process-209393
# Job is not finished
# Successful join: Process-209394
# Job is not finished
# Successful join: Process-209395
# Job is not finished
# Successful join: Process-209396
# Job is not finished
# Successful join: Process-209397
# Job is not finished
# Successful join: Process-209398
# Job is not finished
# Successful join: Process-209399
# Job is not finished
# Successful join: Process-209400
# Job is not finished
# Successful join: Process-209401
# Job is not finished
# Successful join: Process-209402
# Job is not finished
# Successful join: Process-209403
# Job is not finished
# Successful join: Process-209404
# Job is not finished
# Successful join: Process-209405
# Job is not finished
# Successful join: Process-209406
# Job is not finished
# Successful join: Process-209407
# Job is not finished
# Successful join: Process-209408
# Job is not finished
# Successful join: Process-209409
# Job is not finished
# Successful join: Process-209410
# Job is not finished
# Successful join: Process-209411
# Job is not finished
# Successful join: Process-209412
# Job is not finished
# Successful join: Process-209413
# Job is not finished
# Successful join: Process-209414
# Job is not finished
# Successful join: Process-209415
# Job is not finished
# Successful join: Process-209416
# Job is not finished
# Successful join: Process-209417
# Job is not finished
# Successful join: Process-209418
# Job is not finished
# Successful join: Process-209419
# Job is not finished
# Successful join: Process-209420
# Job is not finished
# Successful join: Process-209421
# Job is not finished
# Successful join: Process-209422
# Job is not finished
# Successful join: Process-209423
# Job is not finished
# Successful join: Process-209424
# Job is not finished
# Successful join: Process-209425
# Job is not finished
# Successful join: Process-209426
# Job is not finished
# Successful join: Process-209427
# Job is not finished
# Successful join: Process-209428
# Job is not finished
# Successful join: Process-209429
# Job is not finished
# Successful join: Process-209430
# Job is not finished
# Successful join: Process-209431
# Job is not finished
# Successful join: Process-209432
# Job is not finished
# Successful join: Process-209433
# Job is not finished
# Successful join: Process-209434
# Job is not finished
# Successful join: Process-209435
# Job is not finished
# Successful join: Process-209436
# Job is not finished
# Successful join: Process-209437
# Job is not finished
# Successful join: Process-209438
# Job is not finished
# Successful join: Process-209439
# Job is not finished
# Successful join: Process-209440
# Job is not finished
# Successful join: Process-209441
# Job is not finished
# Successful join: Process-209442
# Job is not finished
# Successful join: Process-209443
# Job is not finished
# Successful join: Process-209444
# Job is not finished
# Successful join: Process-209445
# Job is not finished
# Successful join: Process-209446
# Job is not finished
# Successful join: Process-209447
# Job is not finished
# Successful join: Process-209448
# Job is not finished
# Successful join: Process-209449
# Job is not finished
# Successful join: Process-209450
# Job is not finished
# Successful join: Process-209451
# Job is not finished
# Successful join: Process-209452
# Job is not finished
# Successful join: Process-209453
# Job is not finished
# Successful join: Process-209454
# Job is not finished
# Successful join: Process-209455
# Job is not finished
# Successful join: Process-209456
# Job is not finished
# Successful join: Process-209457
# Job is not finished
# Successful join: Process-209458
# Job is not finished
# Successful join: Process-209459
# Job is not finished
# Successful join: Process-209460
# Job is not finished
# Successful join: Process-209461
# Job is not finished
# Successful join: Process-209462
# Job is not finished
# Successful join: Process-209463
# Job is not finished
# Successful join: Process-209464
# Job is not finished
# Successful join: Process-209465
# Job is not finished
# Successful join: Process-209466
# Job is not finished
# Successful join: Process-209467
# Job is not finished
# Successful join: Process-209468
# Job is not finished
# Successful join: Process-209469
# Job is not finished
# Successful join: Process-209470
# Job is not finished
# Successful join: Process-209471
# Job is not finished
# Successful join: Process-209472
# Job is not finished
# Successful join: Process-209473
# Job is not finished
# Successful join: Process-209474

# %%
print("Execution time - parallel: %s secondes ---" % np.round((time.time() - start_time), 2))
# Out:
# Execution time - parallel: 997.14 secondes ---

# %% [markdown]
# ##### Calcul du RMSE

# %%
# Get the updated p and q
p = modelDSGD_.get_updated_matrix()[0]
q = modelDSGD_.get_updated_matrix()[1]

# %%
R_hat_init = modelDSGD_.get_updated_matrix()[2]
R_hat = np.dot(np.transpose(p), q)

# %%
rmse_init = RMSE(A, R_hat_init, id_x, id_y, nb_ratings)
print('-----')
print('Initial RMSE', rmse_init)
print()
rmse = RMSE(A, R_hat, id_x, id_y, nb_ratings)
print('-----')
print('RMSE', rmse)
print()
print('-----')
print('Gain:', rmse_init - rmse)
# Out:
# -----
# Initial RMSE 3.703971102086721
#
# -----
# RMSE 1.1679263817010908
#
# -----
# Gain: 2.5360447203856302

# %% [markdown]
# ## IV - FSPG Algorithm

# %%
from random import shuffle

def Random_Shuffle_Index(self):
    #shuffle raws
    indices = np.arange(self.shape[0])  
    shuffle(indices)
    #shuffled_matrix = matrix[list(indices)] 
    
    #shuffle columns
    columns = np.arange(self.shape[1])
    shuffle(columns)
    #shuffled_matrix = shuffled_matrix[list(indices)]

    return(np.array(indices),np.array(columns))

# %%
def Grid_Matrix_Sub_Matrix_index(self,s):
    nrow, ncol = self.shape # taille de la matrice de notation
    s=s#Number of spread
    inter_row = nrow//(s+1)
    inter_col = ncol//(s+1)
    dic_row = {}
    dic_col = {}
    for i in range(s):
        dic_row[i] = list(range(i*inter_row, (i+1)*inter_row))
        dic_col[i] = list(range(i*inter_col, (i+1)*inter_col))
    dic_row[i+1] = list(range((i+1)*inter_row, nrow))
    dic_col[i+1] = list(range((i+1)*inter_col, ncol))
    return(dic_row, dic_col)

# %%
def create_real_indexes_Sub_Matrix(self,s):
    dic_row, dic_col = Grid_Matrix_Sub_Matrix_index(self,s)
    real_raws, real_columns = Random_Shuffle_Index(self)
    
    for i in dic_row:
        dic_row[i] = real_raws[dic_row[i]]
        dic_col[i] = real_columns[dic_col[i]]
        dic_row[i]=np.sort(dic_row[i])
    return(dic_row,dic_col)

# %%
Visited_number=np.zeros((len(Sub_Matrix[0]),len(Sub_Matrix[1])))
structure_is_busy=np.zeros((len(Sub_Matrix[0]),len(Sub_Matrix[1])))

def Scheduler(Sub_Matrix, Visited_number, structure_is_busy):
    
    x_mins=np.where(Visited_number==Visited_number.min())[0]
    y_mins=np.where(Visited_number==Visited_number.min())[1]
    Couples_min=[x for x in zip(x_mins,y_mins)]

    x_non_used=np.where(structure_is_busy==0)[0]
    y_non_used=np.where(structure_is_busy==0)[1]
    Couples_non_used=[x for x in zip(x_non_used,y_non_used)]

    Block_to_utpdate=[x for x in Couples_min if x in Couples_non_used][0]
    Index_to_update=Sub_Matrix[0][Block_to_utpdate[0]]
    Colum_to_update=Sub_Matrix[1][Block_to_utpdate[1]]
    
    return(Index_to_update,Colum_to_update)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-e46463032434> in <module>
# ----> 1 Visited_number=np.zeros((len(Sub_Matrix[0]),len(Sub_Matrix[1])))
#       2 structure_is_busy=np.zeros((len(Sub_Matrix[0]),len(Sub_Matrix[1])))
#       3
#       4 def Scheduler(Sub_Matrix, Visited_number, structure_is_busy):
#       5
#
# NameError: name 'Sub_Matrix' is not defined
